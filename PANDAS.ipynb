# %% [markdown]
# <a href="https://colab.research.google.com/github/LaskaMaharjan/MachineLearningg/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### PANDAS 🐼
# 🎀Data Preprocessing in Machine Learning using Pandas
# 🖋️Data preprocessing is required tasks for cleaning the data and making it suitable for a machine learning model which also increases the accuracy and efficiency of a machine learning model.
#
# Pandas is an open source Python package that is most widely used for data science/data analysis and machine learning tasks.It is built on top of another package named as numpy,which provides support for multi-dimensional arrays. Preprocessing is the process of doing a pre-analysis of data, in order to transform them into a standard and normalized format.
#
# 💡Preprocessing involves following:
# - missing values
# - data standardization

# %% [markdown]
# # New Section

# %%
# prompt: import pandas as pd

import pandas as pd
data={
    "cars":["bmw","honda","suzuki","byd"],
    "models":["2007","2008","2015","2024"],
    "passengers":["4","6","6","5"]

}
data
# Out:
# {'cars': ['bmw', 'honda', 'suzuki', 'byd'],
#  'models': ['2007', '2008', '2015', '2024'],
#  'passengers': ['4', '6', '6', '5']}

# %%
# convert the data dictionary to dataframe
df = pd.DataFrame(data)
df
# Out:
#      cars models passengers
# 0     bmw   2007          4
# 1   honda   2008          6
# 2  suzuki   2015          6
# 3     byd   2024          5

# %%
df .to_csv("/content/drive/MyDrive/Colab Notebooks/Carcar_data.csv")

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Carcar_data.csv")
df
# Out:
#    Unnamed: 0    cars  models  passengers
# 0           0     bmw    2007           4
# 1           1   honda    2008           6
# 2           2  suzuki    2015           6
# 3           3     byd    2024           5

# %%
# create a dataframe with two feature calories and duration
import pandas
data = {
  'calories': [420, 500, 390],
  'duration': [50, 60, 45]
}

data
# Out:
# {'calories': [420, 500, 390], 'duration': [50, 60, 45]}

# %%
df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       500        60
# 2       390        45

# %%
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2a851eda2e88> in <cell line: 0>()
# ----> 1 print(df)
#
# NameError: name 'df' is not defined

# %%
print(df.loc[[0,1]])
# Out:
#    calories  duration
# 0       420        50
# 1       500        60

# %%
# create a dataframe with indexing
import pandas as pd
data={
    "calories":[420,380,390],
    "duration":[30,40,45]
}
df=pd.DataFrame(data,index=["day1","day2","day3"])
df
# Out:
#       calories  duration
# day1       420        30
# day2       380        40
# day3       390        45

# %%
print(df.loc[[0,1]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-89c4b57bc868> in <cell line: 0>()
# ----> 1 print(df.loc[[0,1]])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1418                     raise ValueError("Cannot index with multidimensional key")
#    1419
# -> 1420                 return self._getitem_iterable(key, axis=axis)
#    1421
#    1422             # nested tuple slicing
#
# ...

# %%
print(df.loc[["day1","day2"]])
# Out:
#       calories  duration
# day1       420        30
# day2       380        40

# %% [markdown]
# #Data cleaning with pandas
#
# Bad data can be
# - empty cells
# - data in wrong format
# - wrong data
# - duplicates

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Car/dataset(1).csv")
df.head(5)
# Out:
#    Duration  Date        Pulse  Maxpulse  Calories  Unnamed: 5
# 0         0    60  2020/12/01'       110       130       409.1
# 1         1    60  2020/12/02'       117       145       479.0
# 2         2    60  2020/12/03'       103       135       340.0
# 3         3    45  2020/12/04'       109       175       282.4
# 4         4    45  2020/12/05'       117       148       406.0

# %%
df["Pulse"]=df['Pulse'].replace("'","" ,regex=True)
df.head(5)
# Out:
#    Duration  Date       Pulse  Maxpulse  Calories  Unnamed: 5
# 0         0    60  2020/12/01       110       130       409.1
# 1         1    60  2020/12/02       117       145       479.0
# 2         2    60  2020/12/03       103       135       340.0
# 3         3    45  2020/12/04       109       175       282.4
# 4         4    45  2020/12/05       117       148       406.0
